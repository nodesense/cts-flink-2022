# %%
from pyflink.table import EnvironmentSettings, TableEnvironment, DataTypes, CsvTableSource
import datetime
from pyflink.table.expressions import col
from pyflink.table.window import Over, GroupWindow
from pyflink.table.expressions import col, UNBOUNDED_RANGE, CURRENT_RANGE
from pyflink.table.udf import udf
# create a batch TableEnvironment
env_settings = EnvironmentSettings.in_batch_mode()
table_env = TableEnvironment.create(env_settings)

# %%
# InvoiceNo,StockCode,Description,Quantity,InvoiceDate,UnitPrice,CustomerID,Country
# 536365,85123A,WHITE HANGING HEART T-LIGHT HOLDER,6,12/01/2010 8:26,2.55,17850,United Kingdom
column_names = ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 
                'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']

column_types = [DataTypes.STRING(), DataTypes.STRING(), DataTypes.STRING(), DataTypes.DOUBLE(), 
                DataTypes.STRING(), DataTypes.DOUBLE(),DataTypes.STRING(), DataTypes.STRING()]

source = CsvTableSource(
   '../data/1k-dataset.csv',  
    column_names,
    column_types,
    ignore_first_line=True,
    quote_character='"',
    lenient=True
)

# source is data source -origin data is from
# table is flink api
# sink is target where data goes to after transformation
table_env.register_table_source('invoices', source)

# invoices is a table
invoices = table_env.from_path('invoices')


##############################
print('\nRegistered Tables List')
print(table_env.list_tables())

print('\nFinancial Trxs Schema')
invoices.print_schema()
# Out:
# Registered Tables List
# ['invoices']
#
# Financial Trxs Schema
# (
#   `InvoiceNo` STRING,
#   `StockCode` STRING,
#   `Description` STRING,
#   `Quantity` DOUBLE,
#   `InvoiceDate` STRING,
#   `UnitPrice` DOUBLE,
#   `CustomerID` STRING,
#   `Country` STRING
# )

# %%
invoices.fetch(3).execute().print()
# Out:
# +--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+
# |                      InvoiceNo |                      StockCode |                    Description |                       Quantity |                    InvoiceDate |                      UnitPrice |                     CustomerID |                        Country |
# +--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+
# |                         536365 |                         85123A | WHITE HANGING HEART T-LIGHT... |                            6.0 |                12/01/2010 8:26 |                           2.55 |                          17850 |                 United Kingdom |
# |                         536365 |                          71053 |            WHITE METAL LANTERN |                            6.0 |                12/01/2010 8:26 |                           3.39 |                          17850 |                 United Kingdom |
# |                         536365 |                         84406B | CREAM CUPID HEARTS COAT HANGER |                            8.0 |                12/01/2010 8:26 |                           2.75 |                          17850 |                 United Kingdom |
# +--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+--------------------------------+
# 3 rows in set

# %%
#         .column_by_expression("rowtime", "CAST(f0 AS TIMESTAMP(3))") \

# datetime in string format for may 25 1999
input = '12/01/2010 8:26'
  
# format
format = '%d/%m/%Y %H:%M'
  
# convert from string format to datetime format
dt = datetime.datetime.strptime(input, format)
  
# get the date from the datetime using date() 
# function
print(dt)

new_format = '%Y-%m-%d %H:%M:%S'   # SQL Format, which flink can understand
dt.strftime(new_format)
# Out:
# 2010-01-12 08:26:00
# '2010-01-12 08:26:00'

# %%
# UDF - User Defined Function, python/scala/java
# UDF code is not optimized by flink, python udf shall run on Python VM ie python runtime
def convertDateFormat2(input):
    # format
    format = '%d/%m/%Y %H:%M'
  
    # convert from string format to datetime format
    dt = datetime.datetime.strptime(input, format)
    new_format = '%Y-%m-%d %H:%M:%S' 
    return dt.strftime(new_format)

# creating a python function as UDF, first parameter is date string, return type is date string
convertDateFormat = udf(convertDateFormat2, [DataTypes.STRING()], DataTypes.STRING())

# %%
# convert data time string to SQL date time string format as new column CInvoiceDate
# drop Orignal InvoiceDate which is string 
# Cast CInvoiceDate which is SQL date time stirng to TIMESTAMP(3) 3 means precision and 
# create new Column InvoiceDate which TIMESTAMP type
# drop temp col CInvoiceDate
invoices2 = invoices.add_columns(convertDateFormat(col('InvoiceDate')).alias('CInvoiceDate'))\
                    .drop_columns(col('InvoiceDate'))\
                    .add_columns(col("CInvoiceDate").cast(DataTypes.TIMESTAMP(3)).alias("InvoiceDate"))\
                    .drop_columns(col('CInvoiceDate'))\
                    .add_columns( (col("Quantity") * col("UnitPrice")).alias("Amount"))

invoices2.print_schema()
# Out:
# (
#   `InvoiceNo` STRING,
#   `StockCode` STRING,
#   `Description` STRING,
#   `Quantity` DOUBLE,
#   `UnitPrice` DOUBLE,
#   `CustomerID` STRING,
#   `Country` STRING,
#   `InvoiceDate` TIMESTAMP(3),
#   `Amount` DOUBLE
# )

# %%
# DIY
# register invoices2 as table name invoices2
# in table environment, run a select query and display the output

# %%
table_env.register_table('invoices2', invoices2)

# %%
result = table_env.sql_query("SELECT InvoiceNo, Quantity, UnitPrice, Amount from invoices2")
result.fetch(20).execute().print()
# Out:
# +--------------------------------+--------------------------------+--------------------------------+--------------------------------+
# |                      InvoiceNo |                       Quantity |                      UnitPrice |                         Amount |
# +--------------------------------+--------------------------------+--------------------------------+--------------------------------+
# |                         536446 |                            8.0 |                           3.75 |                           30.0 |
# |                         536446 |                            6.0 |                           1.25 |                            7.5 |
# |                         536446 |                           12.0 |                           2.55 |             30.599999999999998 |
# |                         536446 |                           24.0 |                           1.25 |                           30.0 |
# |                         536446 |                            3.0 |                           1.95 |                           5.85 |
# |                         536446 |                            6.0 |                           1.65 |              9.899999999999999 |
# |                         536446 |                            6.0 |                           1.65 |              9.899999999999999 |
# |                         536446 |                           10.0 |                           2.95 |                           29.5 |
# |                         536446 |                            2.0 |                           9.95 |                           19.9 |
# |                         536446 |                            4.0 |                           2.55 |                           10.2 |
# |                         536446 |                            4.0 |                           2.55 |                           10.2 |
# |                         536446 |                           24.0 |                           0.42 |                          10.08 |
# |                         536446 |                           16.0 |                           0.42 |                           6.72 |
# |                         536446 |                           24.0 |                           1.25 |                           30.0 |
# |                         536460 |                           12.0 |                           1.25 |                           15.0 |
# |                         536460 |                           12.0 |                           2.55 |             30.599999999999998 |
# |                         536460 |                           24.0 |                           0.55 |             13.200000000000001 |
# |                         536460 |                           24.0 |                           1.69 |                          40.56 |
# |                         536460 |                           12.0 |                           1.69 |                          20.28 |
# |                         536460 |                            2.0 |                           5.95 |                           11.9 |
# +--------------------------------+--------------------------------+--------------------------------+--------------------------------+
# 20 rows in set

# %%
results = invoices2.group_by ( col("InvoiceNo") )\
                   .select( col("InvoiceNo"), 
                            col("Quantity").sum.alias("Qty"),
                            col("Amount").sum.alias("TotalAmount"),
                            col("InvoiceNo").count.alias("UniqueItems") )

results.execute().print()
# Out:
# +--------------------------------+--------------------------------+--------------------------------+----------------------+
# |                      InvoiceNo |                            Qty |                    TotalAmount |          UniqueItems |
# +--------------------------------+--------------------------------+--------------------------------+----------------------+
# |                         536446 |                          329.0 |                         440.89 |                   32 |
# |                         536466 |                           18.0 |                           42.9 |                    2 |
# |                         536500 |                          102.0 |             223.90000000000003 |                   15 |
# |                         536508 |                          216.0 |                         155.52 |                    2 |
# |                         536514 |                          118.0 |             295.50000000000006 |                    5 |
# |                         536368 |                           15.0 |              70.05000000000001 |                    4 |
# |                         536370 |                          449.0 |                         855.86 |                   20 |
# |                         536371 |                           80.0 |                          204.0 |                    1 |
# |                         536377 |                           12.0 |             22.200000000000003 |                    2 |
# |                         536380 |                           24.0 |                           34.8 |                    1 |
# |                         536382 |                          134.0 |             430.59999999999997 |                   12 |
# |                        C536383 |                           -1.0 |                          -4.65 |                    1 |
# |                         536396 |                          102.0 |             376.36000000000007 |                   18 |
# |                         536397 |                           60.0 |                          279.0 |                    2 |
# |                         536403 |                           97.0 |             192.60000000000002 |                    2 |
# |                         536404 |                          438.0 |             471.29999999999995 |                   28 |
# |                         536409 |                          173.0 |             243.27999999999997 |                   58 |
# |                         536414 |                           56.0 |                            0.0 |                    1 |
# |                         536367 |                           83.0 |                         278.73 |                   12 |
# |                         536372 |                           12.0 |             22.200000000000003 |                    2 |
# |                         536374 |                           32.0 |                          350.4 |                    1 |
# |                         536375 |                           88.0 |                         259.86 |                   16 |
# |                         536381 |                          198.0 |             449.97999999999996 |                   35 |
# |                        C536379 |                           -1.0 |                          -27.5 |                    1 |
# |                         536385 |                           53.0 |                         130.85 |                    7 |
# |                         536387 |                         1440.0 |                        3193.92 |                    5 |
# |                         536388 |                          108.0 |                         226.14 |                   14 |
# |                         536390 |                         1568.0 |                        1825.74 |                   24 |
# |                        C536391 |                         -132.0 |            -141.48000000000002 |                    7 |
# |                         536416 |                          110.0 |                          225.7 |                    6 |
# |                         536437 |                         1004.0 |                         842.12 |                    6 |
# |                         536463 |                           12.0 |                           17.4 |                    1 |
# |                         536464 |                          160.0 |             277.34999999999997 |                   85 |
# |                         536488 |                           72.0 |                         165.89 |                   35 |
# |                         536393 |                            8.0 |                           79.6 |                    1 |
# |                         536395 |                          260.0 |              507.8800000000001 |                   14 |
# |                         536401 |                          124.0 |              354.2299999999999 |                   64 |
# |                         536402 |                          116.0 |                          357.0 |                    3 |
# |                         536460 |                          158.0 |             295.53999999999996 |                   14 |
# |                         536365 |                           40.0 |                         139.12 |                    7 |
# |                         536366 |                           12.0 |             22.200000000000003 |                    2 |
# |                         536373 |                           88.0 |                         259.86 |                   16 |
# |                         536376 |                          112.0 |                          328.8 |                    2 |
# |                         536384 |                          190.0 |                          489.6 |                   13 |
# |                         536386 |                          236.0 |             508.20000000000005 |                    3 |
# |                         536392 |                          103.0 |             318.14000000000004 |                   10 |
# |                         536412 |                          220.0 |              514.4099999999999 |                   81 |
# |                         536423 |                           78.0 |             303.90000000000003 |                    9 |
# |                         536425 |                          137.0 |             362.45000000000005 |                   17 |
# |                         536398 |                          150.0 |             426.56000000000006 |                   17 |
# |                         536399 |                           12.0 |             22.200000000000003 |                    2 |
# |                         536400 |                           12.0 |                           17.4 |                    1 |
# |                         536406 |                           96.0 |             353.14000000000004 |                   17 |
# |                         536407 |                           12.0 |             22.200000000000003 |                    2 |
# |                         536408 |                          558.0 |              783.1099999999999 |                   48 |
# |                         536415 |                          228.0 |             390.78999999999985 |                   59 |
# |                         536420 |                          111.0 |             233.45000000000002 |                   14 |
# |                         536394 |                          544.0 |             1024.6800000000003 |                   11 |
# |                         536405 |                          128.0 |                          326.4 |                    1 |
# |                         536369 |                            3.0 |                          17.85 |                    1 |
# |                         536378 |                          454.0 |                         444.98 |                   19 |
# |                         536389 |                          107.0 |                         358.25 |                   14 |
# |                         536477 |                         1070.0 |             2474.7399999999993 |                   14 |
# |                         536502 |                           39.0 |                          95.29 |                    5 |
# |                        C536506 |                           -6.0 |                          -25.5 |                    1 |
# |                         536520 |                          156.0 |             268.36999999999995 |                   55 |
# +--------------------------------+--------------------------------+--------------------------------+----------------------+
# 66 rows in set

# %%
result = table_env.sql_query("""
SELECT InvoiceNo, sum(Quantity)  as Qty, sum(Amount) as TotalAmount, 
        count(InvoiceNo) as UniqueItems
        
FROM invoices2
GROUP BY InvoiceNo
""")

result.fetch(5).execute().print()
result.print_schema()

# source table
table_env.register_table(  "analytics_results_source", result)
# Out:
# +--------------------------------+--------------------------------+--------------------------------+----------------------+
# |                      InvoiceNo |                            Qty |                    TotalAmount |          UniqueItems |
# +--------------------------------+--------------------------------+--------------------------------+----------------------+
# |                         536393 |                            8.0 |                           79.6 |                    1 |
# |                         536395 |                          260.0 |              507.8800000000001 |                   14 |
# |                         536401 |                          124.0 |              354.2299999999999 |                   64 |
# |                         536402 |                          116.0 |                          357.0 |                    3 |
# |                         536416 |                          110.0 |                          225.7 |                    6 |
# +--------------------------------+--------------------------------+--------------------------------+----------------------+
# 5 rows in set
# (
#   `InvoiceNo` STRING,
#   `Qty` DOUBLE,
#   `TotalAmount` DOUBLE,
#   `UniqueItems` BIGINT NOT NULL
# )

# %%
# create a sink table that prints the output, later will cover mysql/postgres/kafka
table_env.execute_sql("""
CREATE TABLE invoice_temp_sink (
  InvoiceNo STRING,
  Qty DOUBLE,
  TotalAmount DOUBLE,
  UniqueItems  BIGINT NOT NULL
) WITH (
    'connector' = 'print'
)
""")

# %%
# now take results from analytics_results_source table and write to invoice_temp_sink
table_env.execute_sql("INSERT INTO invoice_temp_sink SELECT * FROM analytics_results_source").wait()
# Out:
# 1> +I[536416, 110.0, 225.7, 6]
# 4> +I[536412, 220.0, 514.4099999999999, 81]
# 1> +I[536437, 1004.0, 842.12, 6]
# 4> +I[536423, 78.0, 303.90000000000003, 9]
# 1> +I[536367, 83.0, 278.73, 12]
# 1> +I[536372, 12.0, 22.200000000000003, 2]
# 1> +I[536374, 32.0, 350.4, 1]
# 1> +I[536375, 88.0, 259.86, 16]
# 4> +I[536425, 137.0, 362.45000000000005, 17]
# 1> +I[536381, 198.0, 449.97999999999996, 35]
# 1> +I[C536379, -1.0, -27.5, 1]
# 4> +I[536365, 40.0, 139.12, 7]
# 1> +I[536385, 53.0, 130.85, 7]
# 4> +I[536366, 12.0, 22.200000000000003, 2]
# 1> +I[536387, 1440.0, 3193.92, 5]
# 4> +I[536373, 88.0, 259.86, 16]
# 1> +I[536388, 108.0, 226.14, 14]
# 4> +I[536376, 112.0, 328.8, 2]
# 1> +I[536390, 1568.0, 1825.74, 24]
# 4> +I[536384, 190.0, 489.6, 13]
# 1> +I[C536391, -132.0, -141.48000000000002, 7]
# 1> +I[536393, 8.0, 79.6, 1]
# 1> +I[536395, 260.0, 507.8800000000001, 14]
# 1> +I[536401, 124.0, 354.2299999999999, 64]
# 1> +I[536402, 116.0, 357.0, 3]
# 1> +I[536463, 12.0, 17.4, 1]
# 1> +I[536464, 160.0, 277.34999999999997, 85]
# 1> +I[536488, 72.0, 165.89, 35]
# 2> +I[536396, 102.0, 376.36000000000007, 18]
# 3> +I[536415, 228.0, 390.78999999999985, 59]
# 3> +I[536420, 111.0, 233.45000000000002, 14]
# 3> +I[536394, 544.0, 1024.6800000000003, 11]
# 3> +I[536405, 128.0, 326.4, 1]
# 2> +I[536397, 60.0, 279.0, 2]
# 3> +I[536369, 3.0, 17.85, 1]
# 3> +I[536378, 454.0, 444.98, 19]
# 3> +I[536389, 107.0, 358.25, 14]
# 3> +I[536477, 1070.0, 2474.7399999999993, 14]
# 3> +I[536502, 39.0, 95.29, 5]
# 3> +I[C536506, -6.0, -25.5, 1]
# 2> +I[536403, 97.0, 192.60000000000002, 2]
# 3> +I[536520, 156.0, 268.36999999999995, 55]
# 2> +I[536404, 438.0, 471.29999999999995, 28]
# 2> +I[536409, 173.0, 243.27999999999997, 58]
# 2> +I[536414, 56.0, 0.0, 1]
# 2> +I[536446, 329.0, 440.89, 32]
# 4> +I[536386, 236.0, 508.20000000000005, 3]
# 4> +I[536392, 103.0, 318.14000000000004, 10]
# 2> +I[536466, 18.0, 42.9, 2]
# 4> +I[536398, 150.0, 426.56000000000006, 17]
# 2> +I[536500, 102.0, 223.90000000000003, 15]
# 4> +I[536399, 12.0, 22.200000000000003, 2]
# 2> +I[536508, 216.0, 155.52, 2]
# 4> +I[536400, 12.0, 17.4, 1]
# 2> +I[536514, 118.0, 295.50000000000006, 5]
# 4> +I[536406, 96.0, 353.14000000000004, 17]
# 2> +I[536368, 15.0, 70.05000000000001, 4]
# 4> +I[536407, 12.0, 22.200000000000003, 2]
# 2> +I[536370, 449.0, 855.86, 20]
# 4> +I[536408, 558.0, 783.1099999999999, 48]
# 2> +I[536371, 80.0, 204.0, 1]
# 4> +I[536460, 158.0, 295.53999999999996, 14]
# 2> +I[536377, 12.0, 22.200000000000003, 2]
# 2> +I[536380, 24.0, 34.8, 1]
# 2> +I[536382, 134.0, 430.59999999999997, 12]
# 2> +I[C536383, -1.0, -4.65, 1]

# %%
# create a sink table that prints the output, later will cover mysql/postgres/kafka
table_env.execute_sql("""
CREATE TABLE invoice_temp_sink_mysql (
  InvoiceNo STRING,
  Qty DOUBLE,
  TotalAmount DOUBLE,
  UniqueItems  BIGINT NOT NULL
) WITH (
    'connector' = 'print'
)
""")

# blackhole connector doesn't print anything, does nothing with data, but ignore it
table_env.execute_sql("""
CREATE TABLE invoice_temp_sink_kafka (
  InvoiceNo STRING,
  Qty DOUBLE,
  TotalAmount DOUBLE,
  UniqueItems  BIGINT NOT NULL
) WITH (
    'connector' = 'blackhole'
)
""")

# we have 3 sinks invoice_temp_sink, invoice_temp_sink_mysql, invoice_temp_sink_kafka

# %%
# use statementsets to load and process analytisc once and write results into mulitple destination
# create             statementsets
statement_set = table_env.create_statement_set()

# statement set uisng python using python api

# Emit the result into sink table

statement_set.add_insert("invoice_temp_sink", result) # result is table from analytics query, print console
statement_set.add_insert("invoice_temp_sink_mysql", result) # result is table from analytics query, print console
statement_set.add_insert("invoice_temp_sink_kafka", result) # result is table from analytics query, blackhole, doesn't print

# now execute statement set, this load csv, perform analytics, insert data into all 3 sink tables
statement_set.execute().wait()
# Out:
# 4> +I[536398, 150.0, 426.56000000000006, 17]
# 4> +I[536398, 150.0, 426.56000000000006, 17]
# 4> +I[536399, 12.0, 22.200000000000003, 2]
# 4> +I[536399, 12.0, 22.200000000000003, 2]
# 4> +I[536400, 12.0, 17.4, 1]
# 4> +I[536400, 12.0, 17.4, 1]
# 4> +I[536406, 96.0, 353.14000000000004, 17]
# 4> +I[536406, 96.0, 353.14000000000004, 17]
# 4> +I[536407, 12.0, 22.200000000000003, 2]
# 4> +I[536407, 12.0, 22.200000000000003, 2]
# 4> +I[536408, 558.0, 783.1099999999999, 48]
# 4> +I[536408, 558.0, 783.1099999999999, 48]
# 4> +I[536365, 40.0, 139.12, 7]
# 4> +I[536365, 40.0, 139.12, 7]
# 4> +I[536366, 12.0, 22.200000000000003, 2]
# 4> +I[536366, 12.0, 22.200000000000003, 2]
# 1> +I[536416, 110.0, 225.7, 6]
# 2> +I[536396, 102.0, 376.36000000000007, 18]
# 4> +I[536373, 88.0, 259.86, 16]
# 1> +I[536416, 110.0, 225.7, 6]
# 1> +I[536437, 1004.0, 842.12, 6]
# 1> +I[536437, 1004.0, 842.12, 6]
# 2> +I[536396, 102.0, 376.36000000000007, 18]
# 4> +I[536373, 88.0, 259.86, 16]
# 1> +I[536393, 8.0, 79.6, 1]
# 1> +I[536393, 8.0, 79.6, 1]
# 1> +I[536395, 260.0, 507.8800000000001, 14]
# 2> +I[536397, 60.0, 279.0, 2]
# 1> +I[536395, 260.0, 507.8800000000001, 14]
# 1> +I[536401, 124.0, 354.2299999999999, 64]
# 1> +I[536401, 124.0, 354.2299999999999, 64]
# 1> +I[536402, 116.0, 357.0, 3]
# 2> +I[536397, 60.0, 279.0, 2]
# 1> +I[536402, 116.0, 357.0, 3]
# 1> +I[536367, 83.0, 278.73, 12]
# 1> +I[536367, 83.0, 278.73, 12]
# 1> +I[536372, 12.0, 22.200000000000003, 2]
# 2> +I[536403, 97.0, 192.60000000000002, 2]
# 1> +I[536372, 12.0, 22.200000000000003, 2]
# 1> +I[536374, 32.0, 350.4, 1]
# 1> +I[536374, 32.0, 350.4, 1]
# 4> +I[536376, 112.0, 328.8, 2]
# 2> +I[536403, 97.0, 192.60000000000002, 2]
# 4> +I[536376, 112.0, 328.8, 2]
# 4> +I[536384, 190.0, 489.6, 13]
# 4> +I[536384, 190.0, 489.6, 13]
# 4> +I[536386, 236.0, 508.20000000000005, 3]
# 4> +I[536386, 236.0, 508.20000000000005, 3]
# 4> +I[536392, 103.0, 318.14000000000004, 10]
# 4> +I[536392, 103.0, 318.14000000000004, 10]
# 1> +I[536375, 88.0, 259.86, 16]
# 1> +I[536375, 88.0, 259.86, 16]
# 1> +I[536381, 198.0, 449.97999999999996, 35]
# 2> +I[536404, 438.0, 471.29999999999995, 28]
# 1> +I[536381, 198.0, 449.97999999999996, 35]
# 1> +I[C536379, -1.0, -27.5, 1]
# 2> +I[536404, 438.0, 471.29999999999995, 28]
# 1> +I[C536379, -1.0, -27.5, 1]
# 4> +I[536412, 220.0, 514.4099999999999, 81]
# 1> +I[536385, 53.0, 130.85, 7]
# 4> +I[536412, 220.0, 514.4099999999999, 81]
# 4> +I[536423, 78.0, 303.90000000000003, 9]
# 2> +I[536409, 173.0, 243.27999999999997, 58]
# 4> +I[536423, 78.0, 303.90000000000003, 9]
# 1> +I[536385, 53.0, 130.85, 7]
# 1> +I[536387, 1440.0, 3193.92, 5]
# 4> +I[536425, 137.0, 362.45000000000005, 17]
# 4> +I[536425, 137.0, 362.45000000000005, 17]
# 2> +I[536409, 173.0, 243.27999999999997, 58]
# 1> +I[536387, 1440.0, 3193.92, 5]
# 4> +I[536460, 158.0, 295.53999999999996, 14]
# 2> +I[536414, 56.0, 0.0, 1]
# 1> +I[536388, 108.0, 226.14, 14]
# 2> +I[536414, 56.0, 0.0, 1]
# 4> +I[536460, 158.0, 295.53999999999996, 14]
# 2> +I[536446, 329.0, 440.89, 32]
# 1> +I[536388, 108.0, 226.14, 14]
# 1> +I[536390, 1568.0, 1825.74, 24]
# 2> +I[536446, 329.0, 440.89, 32]
# 1> +I[536390, 1568.0, 1825.74, 24]
# 2> +I[536368, 15.0, 70.05000000000001, 4]
# 2> +I[536368, 15.0, 70.05000000000001, 4]
# 1> +I[C536391, -132.0, -141.48000000000002, 7]
# 1> +I[C536391, -132.0, -141.48000000000002, 7]
# 2> +I[536370, 449.0, 855.86, 20]
# 1> +I[536463, 12.0, 17.4, 1]
# 1> +I[536463, 12.0, 17.4, 1]
# 1> +I[536464, 160.0, 277.34999999999997, 85]
# 2> +I[536370, 449.0, 855.86, 20]
# 1> +I[536464, 160.0, 277.34999999999997, 85]
# 2> +I[536371, 80.0, 204.0, 1]
# 1> +I[536488, 72.0, 165.89, 35]
# 1> +I[536488, 72.0, 165.89, 35]
# 2> +I[536371, 80.0, 204.0, 1]
# 2> +I[536377, 12.0, 22.200000000000003, 2]
# 2> +I[536377, 12.0, 22.200000000000003, 2]
# 2> +I[536380, 24.0, 34.8, 1]
# 2> +I[536380, 24.0, 34.8, 1]
# 2> +I[536382, 134.0, 430.59999999999997, 12]
# 2> +I[536382, 134.0, 430.59999999999997, 12]
# 2> +I[C536383, -1.0, -4.65, 1]
# 2> +I[C536383, -1.0, -4.65, 1]
# 2> +I[536466, 18.0, 42.9, 2]
# 2> +I[536466, 18.0, 42.9, 2]
# 2> +I[536500, 102.0, 223.90000000000003, 15]
# 2> +I[536500, 102.0, 223.90000000000003, 15]
# 2> +I[536508, 216.0, 155.52, 2]
# 2> +I[536508, 216.0, 155.52, 2]
# 2> +I[536514, 118.0, 295.50000000000006, 5]
# 2> +I[536514, 118.0, 295.50000000000006, 5]
# 3> +I[536369, 3.0, 17.85, 1]
# 3> +I[536369, 3.0, 17.85, 1]
# 3> +I[536378, 454.0, 444.98, 19]
# 3> +I[536378, 454.0, 444.98, 19]
# 3> +I[536389, 107.0, 358.25, 14]
# 3> +I[536389, 107.0, 358.25, 14]
# 3> +I[536394, 544.0, 1024.6800000000003, 11]
# 3> +I[536394, 544.0, 1024.6800000000003, 11]
# 3> +I[536405, 128.0, 326.4, 1]
# 3> +I[536405, 128.0, 326.4, 1]
# 3> +I[536477, 1070.0, 2474.7399999999993, 14]
# 3> +I[536477, 1070.0, 2474.7399999999993, 14]
# 3> +I[536502, 39.0, 95.29, 5]
# 3> +I[536502, 39.0, 95.29, 5]
# 3> +I[C536506, -6.0, -25.5, 1]
# 3> +I[C536506, -6.0, -25.5, 1]
# 3> +I[536520, 156.0, 268.36999999999995, 55]
# 3> +I[536520, 156.0, 268.36999999999995, 55]
# 3> +I[536415, 228.0, 390.78999999999985, 59]
# 3> +I[536415, 228.0, 390.78999999999985, 59]
# 3> +I[536420, 111.0, 233.45000000000002, 14]
# 3> +I[536420, 111.0, 233.45000000000002, 14]

# %%
# Now statement set using Flink SQL
# we can mix flink sql and table api
# create statemetn set

# source table: analytics_results_source
# sink target tables   invoice_temp_sink, invoice_temp_sink_mysql, invoice_temp_sink_kafka
statement_set = table_env.create_statement_set()

statement_set.add_insert_sql("INSERT INTO invoice_temp_sink SELECT * FROM analytics_results_source")
statement_set.add_insert_sql("INSERT INTO invoice_temp_sink_mysql SELECT * FROM analytics_results_source")
statement_set.add_insert_sql("INSERT INTO invoice_temp_sink_kafka SELECT * FROM analytics_results_source")

print(statement_set.explain())
# execute the statement set 
statement_set.execute().wait()
# Out:
# == Abstract Syntax Tree ==
# LogicalSink(table=[default_catalog.default_database.invoice_temp_sink], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- LogicalProject(InvoiceNo=[$0], Qty=[$1], TotalAmount=[$2], UniqueItems=[$3])
#    +- LogicalAggregate(group=[{0}], Qty=[SUM($1)], TotalAmount=[SUM($2)], UniqueItems=[COUNT($0)])
#       +- LogicalProject(InvoiceNo=[$0], Quantity=[$3], Amount=[*($3, $5)])
#          +- LogicalTableScan(table=[[default_catalog, default_database, invoices, source: [CsvTableSource(read fields: InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country)]]])
#
# LogicalSink(table=[default_catalog.default_database.invoice_temp_sink_mysql], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- LogicalProject(InvoiceNo=[$0], Qty=[$1], TotalAmount=[$2], UniqueItems=[$3])
#    +- LogicalAggregate(group=[{0}], Qty=[SUM($1)], TotalAmount=[SUM($2)], UniqueItems=[COUNT($0)])
#       +- LogicalProject(InvoiceNo=[$0], Quantity=[$3], Amount=[*($3, $5)])
#          +- LogicalTableScan(table=[[default_catalog, default_database, invoices, source: [CsvTableSource(read fields: InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country)]]])
#
# LogicalSink(table=[default_catalog.default_database.invoice_temp_sink_kafka], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- LogicalProject(InvoiceNo=[$0], Qty=[$1], TotalAmount=[$2], UniqueItems=[$3])
#    +- LogicalAggregate(group=[{0}], Qty=[SUM($1)], TotalAmount=[SUM($2)], UniqueItems=[COUNT($0)])
#       +- LogicalProject(InvoiceNo=[$0], Quantity=[$3], Amount=[*($3, $5)])
#          +- LogicalTableScan(table=[[default_catalog, default_database, invoices, source: [CsvTableSource(read fields: InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country)]]])
#
# == Optimized Physical Plan ==
# Sink(table=[default_catalog.default_database.invoice_temp_sink], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- HashAggregate(isMerge=[true], groupBy=[InvoiceNo], select=[InvoiceNo, Final_SUM(sum$0) AS Qty, Final_SUM(sum$1) AS TotalAmount, Final_COUNT(count$2) AS UniqueItems])
#    +- Exchange(distribution=[hash[InvoiceNo]])
#       +- LocalHashAggregate(groupBy=[InvoiceNo], select=[InvoiceNo, Partial_SUM(Quantity) AS sum$0, Partial_SUM(Amount) AS sum$1, Partial_COUNT(InvoiceNo) AS count$2])
#          +- Calc(select=[InvoiceNo, Quantity, *(Quantity, UnitPrice) AS Amount])
#             +- LegacyTableSourceScan(table=[[default_catalog, default_database, invoices, source: [CsvTableSource(read fields: InvoiceNo, Quantity, UnitPrice)]]], fields=[InvoiceNo, Quantity, UnitPrice])
#
# Sink(table=[default_catalog.default_database.invoice_temp_sink_mysql], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- HashAggregate(isMerge=[true], groupBy=[InvoiceNo], select=[InvoiceNo, Final_SUM(sum$0) AS Qty, Final_SUM(sum$1) AS TotalAmount, Final_COUNT(count$2) AS UniqueItems])
#    +- Exchange(distribution=[hash[InvoiceNo]])
#       +- LocalHashAggregate(groupBy=[InvoiceNo], select=[InvoiceNo, Partial_SUM(Quantity) AS sum$0, Partial_SUM(Amount) AS sum$1, Partial_COUNT(InvoiceNo) AS count$2])
#          +- Calc(select=[InvoiceNo, Quantity, *(Quantity, UnitPrice) AS Amount])
#             +- LegacyTableSourceScan(table=[[default_catalog, default_database, invoices, source: [CsvTableSource(read fields: InvoiceNo, Quantity, UnitPrice)]]], fields=[InvoiceNo, Quantity, UnitPrice])
#
# Sink(table=[default_catalog.default_database.invoice_temp_sink_kafka], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- HashAggregate(isMerge=[true], groupBy=[InvoiceNo], select=[InvoiceNo, Final_SUM(sum$0) AS Qty, Final_SUM(sum$1) AS TotalAmount, Final_COUNT(count$2) AS UniqueItems])
#    +- Exchange(distribution=[hash[InvoiceNo]])
#       +- LocalHashAggregate(groupBy=[InvoiceNo], select=[InvoiceNo, Partial_SUM(Quantity) AS sum$0, Partial_SUM(Amount) AS sum$1, Partial_COUNT(InvoiceNo) AS count$2])
#          +- Calc(select=[InvoiceNo, Quantity, *(Quantity, UnitPrice) AS Amount])
#             +- LegacyTableSourceScan(table=[[default_catalog, default_database, invoices, source: [CsvTableSource(read fields: InvoiceNo, Quantity, UnitPrice)]]], fields=[InvoiceNo, Quantity, UnitPrice])
#
# == Optimized Execution Plan ==
# HashAggregate(isMerge=[true], groupBy=[InvoiceNo], select=[InvoiceNo, Final_SUM(sum$0) AS Qty, Final_SUM(sum$1) AS TotalAmount, Final_COUNT(count$2) AS UniqueItems])(reuse_id=[1])
# +- Exchange(distribution=[hash[InvoiceNo]])
#    +- LocalHashAggregate(groupBy=[InvoiceNo], select=[InvoiceNo, Partial_SUM(Quantity) AS sum$0, Partial_SUM(Amount) AS sum$1, Partial_COUNT(InvoiceNo) AS count$2])
#       +- Calc(select=[InvoiceNo, Quantity, (Quantity * UnitPrice) AS Amount])
#          +- LegacyTableSourceScan(table=[[default_catalog, default_database, invoices, source: [CsvTableSource(read fields: InvoiceNo, Quantity, UnitPrice)]]], fields=[InvoiceNo, Quantity, UnitPrice])
#
# Sink(table=[default_catalog.default_database.invoice_temp_sink], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- Reused(reference_id=[1])
#
# Sink(table=[default_catalog.default_database.invoice_temp_sink_mysql], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- Reused(reference_id=[1])
#
# Sink(table=[default_catalog.default_database.invoice_temp_sink_kafka], fields=[InvoiceNo, Qty, TotalAmount, UniqueItems])
# +- Reused(reference_id=[1])
#
# 2> +I[536409, 173.0, 243.27999999999997, 58]
# 2> +I[536409, 173.0, 243.27999999999997, 58]
# 2> +I[536414, 56.0, 0.0, 1]
# 2> +I[536414, 56.0, 0.0, 1]
# 2> +I[536446, 329.0, 440.89, 32]
# 2> +I[536446, 329.0, 440.89, 32]
# 2> +I[536396, 102.0, 376.36000000000007, 18]
# 2> +I[536396, 102.0, 376.36000000000007, 18]
# 2> +I[536397, 60.0, 279.0, 2]
# 2> +I[536397, 60.0, 279.0, 2]
# 2> +I[536403, 97.0, 192.60000000000002, 2]
# 2> +I[536403, 97.0, 192.60000000000002, 2]
# 2> +I[536404, 438.0, 471.29999999999995, 28]
# 2> +I[536404, 438.0, 471.29999999999995, 28]
# 2> +I[536368, 15.0, 70.05000000000001, 4]
# 2> +I[536368, 15.0, 70.05000000000001, 4]
# 2> +I[536370, 449.0, 855.86, 20]
# 2> +I[536370, 449.0, 855.86, 20]
# 2> +I[536371, 80.0, 204.0, 1]
# 2> +I[536371, 80.0, 204.0, 1]
# 2> +I[536377, 12.0, 22.200000000000003, 2]
# 2> +I[536377, 12.0, 22.200000000000003, 2]
# 2> +I[536380, 24.0, 34.8, 1]
# 2> +I[536380, 24.0, 34.8, 1]
# 2> +I[536382, 134.0, 430.59999999999997, 12]
# 2> +I[536382, 134.0, 430.59999999999997, 12]
# 2> +I[C536383, -1.0, -4.65, 1]
# 2> +I[C536383, -1.0, -4.65, 1]
# 2> +I[536466, 18.0, 42.9, 2]
# 2> +I[536466, 18.0, 42.9, 2]
# 2> +I[536500, 102.0, 223.90000000000003, 15]
# 2> +I[536500, 102.0, 223.90000000000003, 15]
# 2> +I[536508, 216.0, 155.52, 2]
# 2> +I[536508, 216.0, 155.52, 2]
# 2> +I[536514, 118.0, 295.50000000000006, 5]
# 2> +I[536514, 118.0, 295.50000000000006, 5]
# 1> +I[536367, 83.0, 278.73, 12]
# 1> +I[536367, 83.0, 278.73, 12]
# 1> +I[536372, 12.0, 22.200000000000003, 2]
# 1> +I[536372, 12.0, 22.200000000000003, 2]
# 1> +I[536374, 32.0, 350.4, 1]
# 1> +I[536374, 32.0, 350.4, 1]
# 1> +I[536375, 88.0, 259.86, 16]
# 1> +I[536375, 88.0, 259.86, 16]
# 1> +I[536381, 198.0, 449.97999999999996, 35]
# 1> +I[536381, 198.0, 449.97999999999996, 35]
# 1> +I[C536379, -1.0, -27.5, 1]
# 1> +I[C536379, -1.0, -27.5, 1]
# 1> +I[536385, 53.0, 130.85, 7]
# 1> +I[536385, 53.0, 130.85, 7]
# 1> +I[536387, 1440.0, 3193.92, 5]
# 1> +I[536387, 1440.0, 3193.92, 5]
# 1> +I[536388, 108.0, 226.14, 14]
# 1> +I[536388, 108.0, 226.14, 14]
# 1> +I[536390, 1568.0, 1825.74, 24]
# 1> +I[536390, 1568.0, 1825.74, 24]
# 1> +I[C536391, -132.0, -141.48000000000002, 7]
# 1> +I[C536391, -132.0, -141.48000000000002, 7]
# 1> +I[536463, 12.0, 17.4, 1]
# 1> +I[536463, 12.0, 17.4, 1]
# 1> +I[536464, 160.0, 277.34999999999997, 85]
# 1> +I[536464, 160.0, 277.34999999999997, 85]
# 1> +I[536488, 72.0, 165.89, 35]
# 1> +I[536488, 72.0, 165.89, 35]
# 1> +I[536416, 110.0, 225.7, 6]
# 1> +I[536416, 110.0, 225.7, 6]
# 1> +I[536437, 1004.0, 842.12, 6]
# 1> +I[536437, 1004.0, 842.12, 6]
# 1> +I[536393, 8.0, 79.6, 1]
# 1> +I[536393, 8.0, 79.6, 1]
# 1> +I[536395, 260.0, 507.8800000000001, 14]
# 1> +I[536395, 260.0, 507.8800000000001, 14]
# 1> +I[536401, 124.0, 354.2299999999999, 64]
# 1> +I[536401, 124.0, 354.2299999999999, 64]
# 1> +I[536402, 116.0, 357.0, 3]
# 1> +I[536402, 116.0, 357.0, 3]
# 3> +I[536369, 3.0, 17.85, 1]
# 4> +I[536398, 150.0, 426.56000000000006, 17]
# 3> +I[536369, 3.0, 17.85, 1]
# 4> +I[536398, 150.0, 426.56000000000006, 17]
# 3> +I[536378, 454.0, 444.98, 19]
# 3> +I[536378, 454.0, 444.98, 19]
# 4> +I[536399, 12.0, 22.200000000000003, 2]
# 3> +I[536389, 107.0, 358.25, 14]
# 4> +I[536399, 12.0, 22.200000000000003, 2]
# 4> +I[536400, 12.0, 17.4, 1]
# 4> +I[536400, 12.0, 17.4, 1]
# 4> +I[536406, 96.0, 353.14000000000004, 17]
# 4> +I[536406, 96.0, 353.14000000000004, 17]
# 4> +I[536407, 12.0, 22.200000000000003, 2]
# 4> +I[536407, 12.0, 22.200000000000003, 2]
# 4> +I[536408, 558.0, 783.1099999999999, 48]
# 4> +I[536408, 558.0, 783.1099999999999, 48]
# 4> +I[536412, 220.0, 514.4099999999999, 81]
# 4> +I[536412, 220.0, 514.4099999999999, 81]
# 4> +I[536423, 78.0, 303.90000000000003, 9]
# 4> +I[536423, 78.0, 303.90000000000003, 9]
# 4> +I[536425, 137.0, 362.45000000000005, 17]
# 4> +I[536425, 137.0, 362.45000000000005, 17]
# 4> +I[536460, 158.0, 295.53999999999996, 14]
# 4> +I[536460, 158.0, 295.53999999999996, 14]
# 4> +I[536365, 40.0, 139.12, 7]
# 4> +I[536365, 40.0, 139.12, 7]
# 4> +I[536366, 12.0, 22.200000000000003, 2]
# 4> +I[536366, 12.0, 22.200000000000003, 2]
# 4> +I[536373, 88.0, 259.86, 16]
# 4> +I[536373, 88.0, 259.86, 16]
# 4> +I[536376, 112.0, 328.8, 2]
# 4> +I[536376, 112.0, 328.8, 2]
# 4> +I[536384, 190.0, 489.6, 13]
# 4> +I[536384, 190.0, 489.6, 13]
# 4> +I[536386, 236.0, 508.20000000000005, 3]
# 4> +I[536386, 236.0, 508.20000000000005, 3]
# 4> +I[536392, 103.0, 318.14000000000004, 10]
# 4> +I[536392, 103.0, 318.14000000000004, 10]
# 3> +I[536389, 107.0, 358.25, 14]
# 3> +I[536415, 228.0, 390.78999999999985, 59]
# 3> +I[536415, 228.0, 390.78999999999985, 59]
# 3> +I[536420, 111.0, 233.45000000000002, 14]
# 3> +I[536420, 111.0, 233.45000000000002, 14]
# 3> +I[536394, 544.0, 1024.6800000000003, 11]
# 3> +I[536394, 544.0, 1024.6800000000003, 11]
# 3> +I[536405, 128.0, 326.4, 1]
# 3> +I[536405, 128.0, 326.4, 1]
# 3> +I[536477, 1070.0, 2474.7399999999993, 14]
# 3> +I[536477, 1070.0, 2474.7399999999993, 14]
# 3> +I[536502, 39.0, 95.29, 5]
# 3> +I[536502, 39.0, 95.29, 5]
# 3> +I[C536506, -6.0, -25.5, 1]
# 3> +I[C536506, -6.0, -25.5, 1]
# 3> +I[536520, 156.0, 268.36999999999995, 55]
# 3> +I[536520, 156.0, 268.36999999999995, 55]
# 2022-06-08 16:12:10,806 Log4j2-TF-26-ConfiguratonFileWatcher-15 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:14,379 Log4j2-TF-24-ConfiguratonFileWatcher-16 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:21,381 Log4j2-TF-16-ConfiguratonFileWatcher-17 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:21,597 Log4j2-TF-1-ConfiguratonFileWatcher-18 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:22,837 Log4j2-TF-12-ConfiguratonFileWatcher-19 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:23,043 Log4j2-TF-4-ConfiguratonFileWatcher-20 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:25,589 Log4j2-TF-14-ConfiguratonFileWatcher-21 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:26,758 Log4j2-TF-6-ConfiguratonFileWatcher-22 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:31,207 Log4j2-TF-8-ConfiguratonFileWatcher-23 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:31,484 Log4j2-TF-20-ConfiguratonFileWatcher-24 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:32,322 Log4j2-TF-22-ConfiguratonFileWatcher-25 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:38,151 Log4j2-TF-28-ConfiguratonFileWatcher-26 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:38,326 Log4j2-TF-10-ConfiguratonFileWatcher-27 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:38,546 Log4j2-TF-18-ConfiguratonFileWatcher-28 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:40,805 Log4j2-TF-26-ConfiguratonFileWatcher-29 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:44,380 Log4j2-TF-24-ConfiguratonFileWatcher-30 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:51,382 Log4j2-TF-16-ConfiguratonFileWatcher-31 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:51,598 Log4j2-TF-1-ConfiguratonFileWatcher-32 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:52,838 Log4j2-TF-12-ConfiguratonFileWatcher-33 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:53,043 Log4j2-TF-4-ConfiguratonFileWatcher-34 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:55,589 Log4j2-TF-14-ConfiguratonFileWatcher-35 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:12:56,758 Log4j2-TF-6-ConfiguratonFileWatcher-36 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:13:01,207 Log4j2-TF-8-ConfiguratonFileWatcher-37 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:13:01,484 Log4j2-TF-20-ConfiguratonFileWatcher-38 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:13:02,323 Log4j2-TF-22-ConfiguratonFileWatcher-39 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:13:08,152 Log4j2-TF-28-ConfiguratonFileWatcher-40 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:13:08,326 Log4j2-TF-10-ConfiguratonFileWatcher-41 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:13:08,546 Log4j2-TF-18-ConfiguratonFileWatcher-42 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)
# 2022-06-08 16:13:10,805 Log4j2-TF-26-ConfiguratonFileWatcher-43 ERROR Cannot locate file /opt/flink-1.15.0/conf/log4j-cli.properties: java.io.FileNotFoundException: /opt/flink-1.15.0/conf/log4j-cli.properties (No such file or directory)

# %%
print(statement_set.explain())
